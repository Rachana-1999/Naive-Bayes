# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn import preprocessing

# %%
Dataa1 = pd.read_csv("SalaryData_Train(1).csv",encoding = "ISO-8859-1")
Dataa2 = pd.read_csv("SalaryData_Test(1).csv",encoding = "ISO-8859-1")
label_encoder = preprocessing.LabelEncoder()

# %%
from sklearn import preprocessing
label_encoder=preprocessing.LabelEncoder()
Dataa1['Salary']= label_encoder.fit_transform(Dataa1['Salary'])
Dataa2['Salary']= label_encoder.fit_transform(Dataa2['Salary'])
Dataa1["workclass"]=label_encoder.fit_transform(Dataa1['workclass'])
Dataa1["education"]=label_encoder.fit_transform(Dataa1['education'])
Dataa1["maritalstatus"]=label_encoder.fit_transform(Dataa1['maritalstatus'])
Dataa1["occupation"]=label_encoder.fit_transform(Dataa1['occupation'])
Dataa1["relationship"]=label_encoder.fit_transform(Dataa1['relationship'])
Dataa1["race"]=label_encoder.fit_transform(Dataa1['race'])
Dataa1["sex"]=label_encoder.fit_transform(Dataa1['sex'])
Dataa1["native"]=label_encoder.fit_transform(Dataa1['native'])
Dataa2["workclass"]=label_encoder.fit_transform(Dataa2['workclass'])
Dataa2["education"]=label_encoder.fit_transform(Dataa2['education'])
Dataa2["maritalstatus"]=label_encoder.fit_transform(Dataa2['maritalstatus'])
Dataa2["occupation"]=label_encoder.fit_transform(Dataa2['occupation'])
Dataa2["relationship"]=label_encoder.fit_transform(Dataa2['relationship'])
Dataa2["race"]=label_encoder.fit_transform(Dataa2['race'])
Dataa2["sex"]=label_encoder.fit_transform(Dataa2['sex'])
Dataa2["native"]=label_encoder.fit_transform(Dataa2['native'])

# %%
Dataa1
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       39          5          9           13              4           0
# 1       50          4          9           13              2           3
# 2       38          2         11            9              0           5
# 3       53          2          1            7              2           5
# 4       28          2          9           13              2           9
# ...    ...        ...        ...          ...            ...         ...
# 30156   27          2          7           12              2          12
# 30157   40          2         11            9              2           6
# 30158   58          2         11            9              6           0
# 30159   22          2         11            9              4           0
# 30160   52          3         11            9              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# ...

# %%
Dataa1.describe()
# Out:
#                 age    workclass    education   educationno  maritalstatus  \
# count  30161.000000  30161.00000  30161.00000  30161.000000   30161.000000
# mean      38.438115      2.19933     10.33361     10.121316       2.580087
# std       13.134830      0.95394      3.81226      2.550037       1.498018
# min       17.000000      0.00000      0.00000      1.000000       0.000000
# 25%       28.000000      2.00000      9.00000      9.000000       2.000000
# 50%       37.000000      2.00000     11.00000     10.000000       2.000000
# 75%       47.000000      2.00000     12.00000     13.000000       4.000000
# max       90.000000      6.00000     15.00000     16.000000       6.000000
#
#          occupation  relationship          race           sex   capitalgain  \
# count  30161.000000  30161.000000  30161.000000  30161.000000  30161.000000
# mean       5.959849      1.418322      3.678592      0.675707   1092.044064
# ...

# %%
Dataa2.describe()
# Out:
#                 age     workclass     education   educationno  maritalstatus  \
# count  15060.000000  15060.000000  15060.000000  15060.000000   15060.000000
# mean      38.768327      2.214874     10.272377     10.112749       2.595286
# std       13.380676      0.966422      3.826251      2.558727       1.505336
# min       17.000000      0.000000      0.000000      1.000000       0.000000
# 25%       28.000000      2.000000      9.000000      9.000000       2.000000
# 50%       37.000000      2.000000     11.000000     10.000000       2.000000
# 75%       48.000000      2.000000     12.000000     13.000000       4.000000
# max       90.000000      6.000000     15.000000     16.000000       6.000000
#
#          occupation  relationship          race           sex   capitalgain  \
# count  15060.000000  15060.000000  15060.000000  15060.000000  15060.000000
# mean       5.989044      1.401394      3.683665      0.673772   1120.301594
# ...

# %%
from sklearn.tree import DecisionTreeClassifier  #feature engineering to select best values
array=Dataa1.values
X=array[:,0:13]
Y=array[:,13]
model=DecisionTreeClassifier()
model.fit(X,Y)
print(model.feature_importances_)
# Out:
# [0.17467973 0.05080748 0.01622602 0.13067084 0.01138964 0.08024798
#  0.22010455 0.02161435 0.00669238 0.12665126 0.04188386 0.09936849
#  0.01966343]

# %%
data1 = Dataa1.iloc[:,[0,3,6,9,11,13]]
data2 = Dataa2.iloc[:,[0,3,6,9,11,13]]

# %%
data1
# Out:
#        age  educationno  relationship  capitalgain  hoursperweek  Salary
# 0       39           13             1         2174            40       0
# 1       50           13             0            0            13       0
# 2       38            9             1            0            40       0
# 3       53            7             0            0            40       0
# 4       28           13             5            0            40       0
# ...    ...          ...           ...          ...           ...     ...
# 30156   27           12             5            0            38       0
# 30157   40            9             0            0            40       1
# 30158   58            9             4            0            40       0
# 30159   22            9             3            0            20       0
# 30160   52            9             5        15024            40       1
#
# [30161 rows x 6 columns]

# %%
data1.corr()
# Out:
#                    age  educationno  relationship  capitalgain  hoursperweek  \
# age           1.000000     0.043525     -0.246452     0.080152      0.101598
# educationno   0.043525     1.000000     -0.091935     0.124416      0.152522
# relationship -0.246452    -0.091935      1.000000    -0.058257     -0.257850
# capitalgain   0.080152     0.124416     -0.058257     1.000000      0.080431
# hoursperweek  0.101598     0.152522     -0.257850     0.080431      1.000000
# Salary        0.241991     0.335287     -0.250998     0.221195      0.229480
#
#                 Salary
# age           0.241991
# educationno   0.335287
# relationship -0.250998
# capitalgain   0.221195
# hoursperweek  0.229480
# Salary        1.000000

# %%
data2
# Out:
#        age  educationno  relationship  capitalgain  hoursperweek  Salary
# 0       25            7             3            0            40       0
# 1       38            9             0            0            50       0
# 2       28           12             0            0            40       1
# 3       44           10             0         7688            40       1
# 4       34            6             1            0            30       0
# ...    ...          ...           ...          ...           ...     ...
# 15055   33           13             3            0            40       0
# 15056   39           13             1            0            36       0
# 15057   38           13             0            0            50       0
# 15058   44           13             3         5455            40       0
# 15059   35           13             0            0            60       1
#
# [15060 rows x 6 columns]

# %%
data2.corr()
# Out:
#                    age  educationno  relationship  capitalgain  hoursperweek  \
# age           1.000000     0.026123     -0.249701     0.078760      0.102758
# educationno   0.026123     1.000000     -0.081413     0.131750      0.133691
# relationship -0.249701    -0.081413      1.000000    -0.054040     -0.261905
# capitalgain   0.078760     0.131750     -0.054040     1.000000      0.090501
# hoursperweek  0.102758     0.133691     -0.261905     0.090501      1.000000
# Salary        0.227469     0.327813     -0.258335     0.220882      0.222665
#
#                 Salary
# age           0.227469
# educationno   0.327813
# relationship -0.258335
# capitalgain   0.220882
# hoursperweek  0.222665
# Salary        1.000000

# %%
x1_train =  Dataa1.iloc[:,[0,3,9,10,11,13]]
y1_train = Dataa1['Salary']
x1_test = Dataa2.iloc[:,[0,3,9,10,11,13]]
y1_test = Dataa2['Salary']

# %%
Dataa1.isna().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
Dataa2.isna().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
sns.pairplot(data1)

# %%
sns.pairplot(data2)

# %%
x1_train, x1_test, y1_train, y1_test
# Out:
# (       age  educationno  capitalgain  capitalloss  hoursperweek  Salary
#  0       39           13         2174            0            40       0
#  1       50           13            0            0            13       0
#  2       38            9            0            0            40       0
#  3       53            7            0            0            40       0
#  4       28           13            0            0            40       0
#  ...    ...          ...          ...          ...           ...     ...
#  30156   27           12            0            0            38       0
#  30157   40            9            0            0            40       1
#  30158   58            9            0            0            40       0
#  30159   22            9            0            0            20       0
#  30160   52            9        15024            0            40       1
#
#  [30161 rows x 6 columns],
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x1_train = sc.fit_transform(x1_train)
x1_test = sc.transform(x1_test)

# %%
classifier = GaussianNB()
classifier.fit(x1_train, y1_train)
# Out:
# GaussianNB()

# %%
y_pred = classifier.predict(x1_test) 
y_pred
# Out:
# array([0, 0, 1, ..., 0, 0, 1])

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y1_test, y_pred)
from sklearn.metrics import accuracy_score 
print ("Accuracy : ", accuracy_score(y1_test, y_pred))
cm
# Out:
# Accuracy :  1.0
# array([[11360,     0],
#        [    0,  3700]], dtype=int64)

# %%
plt.hist(y1_test,color='m');

# %%
plt.hist(y_pred,color='c');

# %%
df = pd.DataFrame({'Real Values':y1_test, 'Predicted Values':y_pred})
df
# Out:
#        Real Values  Predicted Values
# 0                0                 0
# 1                0                 0
# 2                1                 1
# 3                1                 1
# 4                0                 0
# ...            ...               ...
# 15055            0                 0
# 15056            0                 0
# 15057            0                 0
# 15058            0                 0
# 15059            1                 1
#
# [15060 rows x 2 columns]
